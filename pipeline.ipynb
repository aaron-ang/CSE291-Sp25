# %%
import os
import pandas as pd
import re
import numpy as np

# %%
# Read the  dataset
def read_dataset(file_path):
    """
    Reads the dataset from the given file path.
    :param file_path: Path to the dataset file.
    :return: DataFrame containing the dataset.
    """
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"File {file_path} does not exist.")

    # Read the dataset
    df = pd.read_csv(file_path)

    return df


df = read_dataset("data/mq_variants_intensity_cleaned.csv")

# %%
df.head()
# Out:
#                   Variant  Variant ID           Unmod variant  Total  \
# 0   .VADPDHDHTGFLTEYVATR.       93378   .VADPDHDHTGFLTEYVATR.  11372
# 1  .LGEHNIDVLEGNEQFINAAK.       50733  .LGEHNIDVLEGNEQFINAAK.   8878
# 2        .FRHENIIGINDIIR.       25741        .FRHENIIGINDIIR.   8720
# 3        .ESESTAGSFSLSVR.       21292        .ESESTAGSFSLSVR.   7995
# 4             .NYLLSLPHK.       68115             .NYLLSLPHK.   7445
#
#    Total- Unmodified sequence  Variants- Unmodified sequence  \
# 0                       15019                             62
# 1                       23098                            134
# 2                       12619                             33
# 3                        8328                              7
# 4                       11842                             41
#
#                                             Proteins    Mass  Charge  \
# 0        sp|P28482-2|MK01_HUMAN;sp|P28482|MK01_HUMAN  2144.0       2
# 1                                           TRYP_PIG  2211.1       2
# 2        sp|P28482-2|MK01_HUMAN;sp|P28482|MK01_HUMAN  1709.9       2
# 3  sp|P06239-2|LCK_HUMAN;sp|P06239-3|LCK_HUMAN;sp...  1456.7       2
# 4                               sp|P28482|MK01_HUMAN  1084.6       2
#
#    Num Mods  ... _dyn_#Baricitinib 300nM.Tech replicate 1 of 1  \
# 0         0  ...                                   182810000.0
# 1         0  ...                                   152910000.0
# 2         0  ...                                   115160000.0
# 3         0  ...                                    19220000.0
# 4         0  ...                                   290970000.0
#
#    _dyn_#Baricitinib 300nM.Tech replicate 1 of 1_unmod  \
# 0                                        182810000.0
# 1                                        152910000.0
# 2                                        115160000.0
# 3                                         19220000.0
# 4                                        290970000.0
#
#   _dyn_#Baricitinib 30nM.Tech replicate 1 of 1  \
# 0                                  296340000.0
# 1                                  313690000.0
# 2                                  223460000.0
# 3                                   11216000.0
# 4                                  477300000.0
#
#    _dyn_#Baricitinib 30nM.Tech replicate 1 of 1_unmod  \
# 0                                        296340000.0
# 1                                        313690000.0
# 2                                        223460000.0
# 3                                         11216000.0
# 4                                        477300000.0
#
#   _dyn_#Baricitinib 3nM.Tech replicate 1 of 1  \
# 0                                 272890000.0
# 1                                 187600000.0
# 2                                 182890000.0
# 3                                  12721000.0
# 4                                 363140000.0
#
#    _dyn_#Baricitinib 3nM.Tech replicate 1 of 1_unmod  \
# 0                                        272890000.0
# 1                                        187600000.0
# 2                                        182890000.0
# 3                                         12721000.0
# 4                                        363140000.0
#
#    _dyn_#Baricitinib DMSO.Tech replicate 1 of 1  \
# 0                                   254860000.0
# 1                                   313290000.0
# 2                                   236530000.0
# 3                                    12835000.0
# 4                                    43697000.0
#
#   _dyn_#Baricitinib DMSO.Tech replicate 1 of 1_unmod  \
# 0                                        254860000.0
# 1                                        313290000.0
# 2                                        236530000.0
# 3                                         12835000.0
# 4                                         43697000.0
#
#   _dyn_#Baricitinib PDPD.Tech replicate 1 of 1  \
# 0                                   70792000.0
# 1                                  204790000.0
# 2                                   97725000.0
# 3                                    8137600.0
# 4                                  182850000.0
#
#   _dyn_#Baricitinib PDPD.Tech replicate 1 of 1_unmod
# 0                                         70792000.0
# 1                                        204790000.0
# 2                                         97725000.0
# 3                                          8137600.0
# 4                                        182850000.0
#
# [5 rows x 1031 columns]

# %%
# Filter rows where Proteins column doesn't contain a semicolon
single_protein_variants = df[~df['Proteins'].str.contains(';', na=False)]

# Display the shape of the original and filtered dataframes
print(f"Original dataset shape: {df.shape}")
print(f"Filtered dataset shape: {single_protein_variants.shape}")

# Display first few rows of the filtered dataset
single_protein_variants.head()
# Out:
# Original dataset shape: (50659, 1031)
# Filtered dataset shape: (9594, 1031)
#                           Variant  Variant ID           Unmod variant  Total  \
# 1          .LGEHNIDVLEGNEQFINAAK.       50733  .LGEHNIDVLEGNEQFINAAK.   8878
# 4                     .NYLLSLPHK.       68115             .NYLLSLPHK.   7445
# 9                .KLEAAEDIAYQLSR.       44634        .KLEAAEDIAYQLSR.   4958
# 11         .IITHPNFNGNTLDNDIMLIK.       37659  .IITHPNFNGNTLDNDIMLIK.   4830
# 25  .L+28.003GEHNIDVLEGNEQFINAAK.       50735  .LGEHNIDVLEGNEQFINAAK.   3782
#
#     Total- Unmodified sequence  Variants- Unmodified sequence  \
# 1                        23098                            134
# 4                        11842                             41
# 9                         6905                             36
# 11                       20735                             81
# 25                       23098                            134
#
#                 Proteins    Mass  Charge  Num Mods  ...  \
# 1               TRYP_PIG  2211.1       2         0  ...
# 4   sp|P28482|MK01_HUMAN  1084.6       2         0  ...
# 9    sp|P35232|PHB_HUMAN  1606.8       2         0  ...
# 11              TRYP_PIG  2283.2       2         0  ...
# 25              TRYP_PIG  2239.1       2         1  ...
#
#    _dyn_#Baricitinib 300nM.Tech replicate 1 of 1  \
# 1                                    152910000.0
# 4                                    290970000.0
# 9                                     32624000.0
# 11                                           NaN
# 25                                           NaN
#
#     _dyn_#Baricitinib 300nM.Tech replicate 1 of 1_unmod  \
# 1                                         152910000.0
# 4                                         290970000.0
# 9                                          32624000.0
# 11                                                NaN
# 25                                        152910000.0
#
#    _dyn_#Baricitinib 30nM.Tech replicate 1 of 1  \
# 1                                   313690000.0
# 4                                   477300000.0
# 9                                    55130000.0
# 11                                          NaN
# 25                                          NaN
#
#     _dyn_#Baricitinib 30nM.Tech replicate 1 of 1_unmod  \
# 1                                         313690000.0
# 4                                         477300000.0
# 9                                          55130000.0
# 11                                                NaN
# 25                                        313690000.0
#
#    _dyn_#Baricitinib 3nM.Tech replicate 1 of 1  \
# 1                                  187600000.0
# 4                                  363140000.0
# 9                                   52332000.0
# 11                                         NaN
# 25                                         NaN
#
#     _dyn_#Baricitinib 3nM.Tech replicate 1 of 1_unmod  \
# 1                                         187600000.0
# 4                                         363140000.0
# 9                                          52332000.0
# 11                                                NaN
# 25                                        187600000.0
#
#     _dyn_#Baricitinib DMSO.Tech replicate 1 of 1  \
# 1                                    313290000.0
# 4                                     43697000.0
# 9                                     52156000.0
# 11                                           NaN
# 25                                           NaN
#
#    _dyn_#Baricitinib DMSO.Tech replicate 1 of 1_unmod  \
# 1                                         313290000.0
# 4                                          43697000.0
# 9                                          52156000.0
# 11                                                NaN
# 25                                        313290000.0
#
#    _dyn_#Baricitinib PDPD.Tech replicate 1 of 1  \
# 1                                   204790000.0
# 4                                   182850000.0
# 9                                    55709000.0
# 11                                          NaN
# 25                                          NaN
#
#    _dyn_#Baricitinib PDPD.Tech replicate 1 of 1_unmod
# 1                                         204790000.0
# 4                                         182850000.0
# 9                                          55709000.0
# 11                                                NaN
# 25                                        204790000.0
#
# [5 rows x 1031 columns]

# %%
single_protein_variants.to_csv("data/mq_variants_intensity_single_protein.csv", index=False)
